# %%
'''
下面是处理完三元组之后如何利用它们构建知识图谱（因此不要担心你的知识图谱的实体不能连接在一起）

1.识别唯一实体：因为我们的三元组已经是主谓宾的结构，因此可以直接从三元组的主语和宾语位置提取所有唯一的实体，这些实体将成为知识图中的节点

2.创建节点：在知识图谱中为每个识别出的唯一实体创建一个节点，为每个节点分配一个唯一的标识符或标签

3.创建关系：将三元组中的谓词映射到知识图谱中的关系上 -- 对于每个三元组，根据谓词在相应的主语和宾语节点之间创建一个关系
（注意，知识图谱与其他数据结构不同的地方就在于两个实体之间是可以存在多种不同的关系的，而传统的图或关系数据库模型中，实体之间的关系通常局限于一种类型）

'''
import pandas as pd
import csv

# %%
# 读取三元组文件
h_r_t_name = [":START_ID", "role", ":END_ID"]
h_r_t = pd.read_table("./data/handle_triples_data.txt", decimal="\t", names=h_r_t_name)
print(h_r_t.info())
print(h_r_t.head())

# 去除重复实体
entity = set()
entity_h = h_r_t[':START_ID'].tolist()
entity_t = h_r_t[':END_ID'].tolist()
for i in entity_h:
    entity.add(i)
for i in entity_t:
    entity.add(i)
print(entity)
# 保存节点文件
csvf_entity = open("./data/entity.csv", "w", newline='', encoding='utf-8')
w_entity = csv.writer(csvf_entity)
# 实体ID，要求唯一，名称，LABEL标签，可自己不同设定对应的标签
w_entity.writerow(("entity:ID", "name", ":LABEL"))
entity = list(entity)
entity_dict = {}
for i in range(len(entity)):
    w_entity.writerow(("e" + str(i), entity[i], "my_entity"))
    entity_dict[entity[i]] = "e"+str(i)
csvf_entity.close()
# 生成关系文件，起始实体ID，终点实体ID，要求与实体文件中ID对应，:TYPE即为关系
h_r_t[':START_ID'] = h_r_t[':START_ID'].map(entity_dict)
h_r_t[':END_ID'] = h_r_t[':END_ID'].map(entity_dict)
h_r_t[":TYPE"] = h_r_t['role']
h_r_t.pop('role')
h_r_t.to_csv("./data/roles.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4554 entries, 0 to 4553
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   :START_ID  4554 non-null   object
#  1   role       4554 non-null   object
#  2   :END_ID    4554 non-null   object
# dtypes: object(3)
# memory usage: 106.9+ KB
# None
#            :START_ID role :END_ID
# 0                天水地   出现   强降雨过程
# 1                 损失    是      惨重
# 2               受灾范围  集中在     福建省
# 3               受灾范围   搜救    失踪人员
# 4  四川省雅安市汉源县万工乡境内后背山   发生    山体滑坡
# {'民政部调运物资', '宜昌市自然灾害救助指挥部', '危房动员老百姓转移', '距离', '各地确保专款专用', '小二型康家沟水库', '极端天气影响', '遭受洪涝风雹灾害的', '县城多处被淹', '支持', '千亩以上圩堤溃决', '农业部门组成工作组', '当天通报', '九江地', '强降雨是直接原因', '腾空库容', '新居', '福建省份遭受洪涝风雹灾害', '临街商铺', '重庆主城', '较大挑战', '常年同期2.9倍', '来自拉萨市政府防汛抗旱指挥办公室消息', '要求', '大家', '多生活可以', '货物专用车', '藏镍矿修路', '地', '当前处于防汛关键时刻', '吃菜', '副总理汪洋', '化工原料桶', '三明局地降雨量', '贵州遭受袭击造成19个县市发生洪涝灾害', '大量房屋', '危险区域', '山洪自然灾害', '陕西洪涝灾区民房重建', '洪涝灾害损失统计指标', '很多游客', '地质灾害气象风险', '黄泽元', '此次灾害原因之一', '强降雨致41个县市遭受洪涝灾害', '盆地湖', '遭洪水袭击湘北局地', '保证', '阿坝州汶川县映秀镇', '朱世强侯志红甘肃舟曲特大山洪泥石流灾害抢险救灾指挥部新闻中心', '直接经济损失达1.75亿元人民币', '三条流域片区', '处龟兹矿业附近山谷', '严重渭南市', '各项指标', '报制', '云南昆明193毫米', '岩石崩塌', '一个强降雨云带', '该县发生山洪灾害导致5人死亡', '第一个灾区', '严卫东主任', '转移受灾群众', '还有一个多月', '甘肃庆阳设备公司', '特大洪灾救援现场', '引水隧洞突遇4人致遇难', '中下游地', '核灾工作重点', '山阴县', '抚远江段', '受灾县市中超过5成以上', '致电线落地', '全国1311.9万人次受灾', '柳树泉农场', '万人9.9受灾', '广东省公安消防总队', '石羊哨段', '灾区各地', '地质灾害发生数量', '安顺市关岭县', '党政正职', '教育卫生机构', '多数民宅', '凯圩内', '如何', '转移', '陇南市宕昌县出现降雨天气', '深入', '救援队挖出', '龙尾位置', '防治县', '本次天气过程', '六十公分以下', '中央预算水利资金', '一个4岁孙女', '牟定县委书记李绍文', '十万人受困', '干流湟源水文站', '嘉陵江水位', '防办人士', '年久失修房屋', '镇单日', '扎草路抢修', '水利抢险工作组', '直接', '东北冷涡影响', '浮梁地', '张家团', '调度', '王儒林领导', '治理工程', '超历史实测记录大洪水', '梧州市藤县', '赵牛新河禹城段险情', '周红波', '汉江大堤', '江西持续暴雨天气', '超过', '县城一片汪洋', '疏散民众', '副总工程师陈文军', '广西保持高度警惕', '安徽安庆201毫米', '被淹', '索通村段', '李克强', '阶段性成果', '灾后生产自救', '崔亮辰', '洪水下泄', '诸多省份', '普降大', '巧家县委书记方宗辉', '防汛紧急状态', '部分城镇', '中央自然灾害生活补助资金', '朔州地强降雨引发洪涝灾害致使', '待产孕妇', '许多灾民', '最近一次', '桂西干旱区域', '每平方公里', '一口气', '嫩江县防办', '薄弱环节', '这次强降雨过程造成13个市州', '搜救中', '长江中下游', '连续性暴雨过程', '干流河流', '洪涝灾害致95个县', '浙江安徽新疆', '重庆市抢险中心', '村落瑞金市瑞林镇民主村', '省委领导精神', '人遇难', '西双版纳', '副高控制', '部分中小河水位县域内长潭河暴涨', '隐患', '齐腰深', '几天时间', '严重旱情', '洪涝灾害呈现以下特点', '著名景点', '漫过', '河池东南部', '灾区群众吃饭', '咸宁市组织部队', '达州市气象台消息', '木竹村交界响水沟地段', '高方式', '暴发洪灾造成经济损失超过1000万元人民币', '泥泞路段', '调运3万床棉被', '今年', '六安市金寨县', '洪流对岸', '突降单点暴雨', '河北省张家口市农牧局谭地宋锦丰', '暴露一些问题', '江西信江中游赣江上游支流琴江', '三成以上', '针对此次灾情', '级救灾应急响应启动', '常务副总指挥黄泽元', '出现等山洪灾情', '一些群众', '湖北沙洋', '两支救援队', '防汛抢险存在一些困难', '湘江湘潭站', '受到严重影响的', '边防派出所', '国家防总派工作组', '通知', '受损国道', '雅安市雨城区', '民房遭受冲击', '民政部门配合有关部门', '伙食救助点', '内蒙古大兴安岭地区', '救援力量', '多处航道航段', '导致都江堰市中兴镇三溪村突发山体滑坡', '抚慰金', '库车县组织', '赣南灾区村民盼迁移', '受灾范围', '该县猛硐乡遭受强降雨袭击引发洪涝灾害', '各级安排望谟县收到2065万元捐款', '先后', '大部分灾民', '吉林中部局地', '全乡断水', '国家防总坚持放在首位', '一座山城', '指示', '红色预警', '严重仁化城口镇', '上万户居民', '一所中学内', '宁夏黄河支流红柳河发生最大洪水', '国家防汛抗旱总指挥部办公室举行发布会', '小沙坪站', '重庆市气象台台长刘德', '江西遭受袭击', '中北部出现大雨', '损毁饮水工程3566处', '拨款程序', '李华', '排洪调度', '保证4.66米', '武警交通部队', '民众提供情况', '部门政府办公大楼内', '上千万元', '低槽东移', '一号命令', '漫堤险情', '致1人失踪灾害', '黑龙江洪灾', '炉房沟山洪暴发', '下游流域', '湖北有累计雨量达暴雨量级', '村民们', '导致游客困情况', '甘肃省天水市', '民政部副部长孙绍骋', '江南地', '达222毫米', '拉萨市政府防汛抗旱指挥办公室', '大范围降雨', '河南468个乡镇', '捐助款物', '辽宁吉林局地', '赣北东部', '重现98年洪灾', '新疆军区派出直升飞机', '抗洪专家组', '鹿心社领导', '淤泥厚', '一栋楼倒塌', '下阶段做好搜救工作', '地质隐患威胁', '欧亚中高纬大气环流', '市长书记', '九江市共有累计降雨超过50毫米', '百色市田林县利周乡平布村尾央屯', '多地雨量创下', '事发现场', '四川渠县洪灾', '皖南山区', '营救工作', '新疆库车县山区', '确实', '房屋倒塌', '转移1550人', '中华全国总工会拨付救灾款', '不少民房', '配变设备恢复', '当地共有7.7万人受灾', '倒塌民房7677户', '受灾面积达1946千公顷', '国家防总办公室副主任束庆鹏', '有的', '内蒙古赤峰', '国务院政策例行吹风会', '供水设施摧毁', '至长江中下游一带', '广西水利厅', '多年同期', '安康城区防汛指挥部', '此次暴雨', '下降', '降水量事件', '各地灾情', '台风', '包括居民家中进水电话', '五大特点', '部分县区', '总面积10%', '重点站', '陆浑水库泄洪', '来水增多', '逾8万人大暴雨', '不同作业区', '近期长江上中', '固阳县西斗铺镇有2人死亡', '重灾区永吉县', '附近宾馆里', '受菲特影响', '易镇', '坝体垮塌', '伊犁州新源县', '严重经济损失', '抚顺市', '分散性', '核查房屋情况', '冲锋艇设备', '办公楼一楼房屋', '特大暴雨造成43.25万人受灾', '内蒙古红花尔基水库泄洪', '驶进高速路口', '中国7677万人', '山洪自然灾害造成受灾', '贵东有中', '江西省气候中心', '溃坝的话', '红河哈尼族彝族自治州金平苗族瑶族傣族自治县遭受洪涝', '这次爆破', '国家防总副总指挥黄明', '治疗', '医疗组', '由于', '苏甲乡', '朔州地强降雨', '刘俊', '河流堤防', '最远村子', '全遵合', '防疫组', '绵阳市支援', '展开救援', '该省洪灾损失情况', '高速公路养护管理部门', '部分山区发生山体滑坡灾害', '多方力量', '无人员伤亡报告', '商铺经营者', '一辆出租车', '强降水落区位', '兰州军区某防化团', '人为活动因素', '株洲城市', '下面', '坏天气致使', '超过保证水位洪峰', '尾声', '少35%', '伊犁河谷出现降雨天气', '王瑞程', '多个省市', '阿拉善左旗巴', '前期旱情', '灾情偏重', '蔬菜', '受切变', '福州区间', '当雄县雪山融雪', '江津区', '发展变化', '永善县发生山洪灾害', '深圳市南山区', '投入', '主要落区集中', '一带遭受强过程', '雨量大', '其中之一', '返贫', '武汉市新洲区举水河', '驻山东蓬莱B-7313直升机', '德阳地', '女儿', '第二大洪峰', '刘忠俊姜学华', '陇南市农村公路抢通情况', '悼念活动', '其他', '都 ...

# %% [markdown]
# csv文件直接使用excel打开一般会出现乱码，推荐将其使用excel的导入功能进行导入进而可视化
