# %%
'''
本部分是基于依存句法分析提取文本中的(实体,关系,实体)三元组的代码，主要借助的是百度的DDParser工具
'''
import os, re
from ddparser import DDParser

# %%
# 基于百度DDParser依存句法分析的SVO三元组抽取
class SVOParser:
    def __init__(self):
        self.parser = DDParser(use_pos=True) # 依存句法分析器
        print('loaded model')

    '''
    文章分句处理, 切分长句，冒号，分号，感叹号等做切分标识
    '''

    def split_sents(self, content):
        return [sentence for sentence in re.split(r'[？?！!。；;：:\n\r]', content) if sentence]

    '''
    句法分析---为句子中的每个词语维护一个保存句法依存儿子节点的字典    
    '''
    def build_parse_child_dict(self, words, postags, rel_id, relation):
        child_dict_list = [] # 保存句法依存儿子节点的字典
        format_parse_list = [] # 保存格式化后的依存关系
        for index in range(len(words)):
            child_dict = dict() # 空字典child_dict
            for arc_index in range(len(rel_id)): # 使用arc_index变量迭代rel_id列表的索引
                if rel_id[arc_index] == index+1:   # 检查arc_index处的rel_id值是否等于index+1，如果是，则表示依赖关系对应于索引处的当前单词。然后，代码相应地更新child_dict
                    if rel_id[arc_index] in child_dict: # 如果当前的rel_id值已经作为关键字存在于child_dict中，则arc_index会附加到相应的索引列表中
                        child_dict[relation[arc_index]].append(arc_index)
                    else: # 否则，将创建一个新键，并将其值初始化为包含arc_index的空列表
                        child_dict[relation[arc_index]] = []
                        child_dict[relation[arc_index]].append(arc_index)
            child_dict_list.append(child_dict) # 在处理了当前单词的所有依赖关系后，child_dict被附加到child_dict_list
        heads = ['Root' if id == 0 else words[id - 1] for id in rel_id]  # 将每个依赖关系id与其对应的单词匹配，若id为0则为根节点
        for i in range(len(words)):
            a = [relation[i], words[i], i, postags[i], heads[i], rel_id[i]-1, postags[rel_id[i]-1]] # 为每个单词创建解析信息的格式化表示
            format_parse_list.append(a)
        # child_dict_list包含每个单词的依赖关系，format_parse_list包含每个单词的格式化解析信息
        return child_dict_list, format_parse_list

    '''
    parser主函数
    '''
    def parser_main(self, sentence):
        res = self.parser.parse(sentence, )[0] # 调用DDParser的parse方法，对句子进行依存句法分析
        # 分别将解析的结果提取出来
        words = res["word"]
        postags = res["postag"]
        rel_id = res["head"]
        relation = res["deprel"]
        # 根据提取的信息构建解析树结构，并返回两个值：child_dict_list 和 format_parse_list
        child_dict_list, format_parse_list = self.build_parse_child_dict(words, postags, rel_id, relation) # 调用build_parse_child_dict方法，为句子中的每个词语维护一个保存句法依存儿子节点的字典
        return words, postags, child_dict_list, format_parse_list # 该方法返回解析后的词语、词性标注、以子字典列表形式表示的解析树（child_dict_list）以及格式化的解析列表（format_parse_list）

    """
    将所有的ATT进行合并
    """
    def merge_ATT(self, words, postags, format_parse_list):
        words_ = words # 浅拷贝
        retain_nodes = set()
        ATTs = []
        ATT = []
        format_parse_list_ = []
        for parse in format_parse_list: # 遍历format_parse_list集合，每个parse都是一个包含特定依存关系信息的列表
            dep = parse[0]
            if dep in ['ATT', 'ADV']: # 如果依存关系是ATT或ADV，则将其添加到ATT列表中
                ATT += [parse[2], parse[5]]
            else: # 如果依存类型不是 'ATT' 或 'ADV'，代码会检查 ATT 列表是否为空
                if ATT: # 如果ATT列表不为空，则将其合并为一个字符串，并将其添加到ATTs列表中
                    body = ''.join([words[i] for i in sorted(set(ATT))])
                    ATTs.append(body) # 将 ATT 列表中索引对应的词连接起来形成一个单词（body），并将其添加到 ATTs 列表中
                    retain_nodes.add(sorted(set(ATT))[-1]) # 将 ATT 列表中最后一个索引添加到retain_nodes集合中
                    words_[sorted(set(ATT))[-1]] = body # 将 ATT 列表中最后一个索引对应的词替换为body
                else:
                    retain_nodes.add(parse[2]) # 如果 ATT 列表为空，意味着序列中没有 'ATT' 或 'ADV' 依存关系，此时只需将当前 parse 的索引添加到 retain_nodes 集合中即可
                ATT = []
        for indx, parse in enumerate(format_parse_list):
            if indx in retain_nodes: # 检查当前索引（indx）是否存在于 retain_nodes 集合中
                parse_ = [parse[0], words_[indx], indx, postags[indx], words_[parse[5]], parse[5], postags[parse[5]]] # 如果存在，则将该索引对应的词替换为words_[indx]
                format_parse_list_.append(parse_) # 将该parse_添加到format_parse_list_中
        return words_, postags, format_parse_list_, retain_nodes

    """
    根据词性标注（postags）、依存解析（child_dict_list）和其他语言信息从给定的句子中提取语义三元组（主语-动词-宾语关系）
    该方法旨在通过利用词性标注和依存解析信息从句子中提取主谓宾和主谓补关系，提取的三元组提供了关于句子的语义结构和关系的见解
    """
    def extract(self, words, postags, child_dict_list, arcs, retain_nodes):
        svos = [] # 用于保存抽取出的三元组
        for index in range(len(postags)): # 遍历句子中的每个词
            if index not in retain_nodes: # 如果该词不在retain_nodes集合中，则跳过该词 -- 只考虑对句子中的特定节点进行提取
                continue
            # 检查给定索引处的当前词语是否具有非空的词性标注（postags[index]）。如果不为空，则根据句法结构提取语义三元组
            if postags[index]:
                child_dict = child_dict_list[index] # 获取当前词语的依存解析信息
                # 查找主谓宾（SVO）三元组，通过检查是否存在主语（SBV）和宾语（VOB）作为子节点来确定
                if 'SBV' in child_dict and 'VOB' in child_dict:
                    r = words[index] # 提取谓语(动词)
                    e1 = words[child_dict['SBV'][0]] # 提取主语
                    e2 = words[child_dict['VOB'][0]] # 提取宾语
                    if e1.replace(' ', '') and e2.replace(' ', ''): 
                        svos.append([e1, r, e2]) # 提取的主语（e1）、动词（r）和宾语（e2）以语义三元组[e1, r, e2]的形式添加到svos列表中，分别表示主语、动词和宾语

                # 通过查找主语（SBV）和补语（CMP）关系来检查主谓补（SVC）三元组是否存在
                if 'SBV' in child_dict and 'CMP' in child_dict:
                    e1 = words[child_dict['SBV'][0]] # 提取主语
                    cmp_index = child_dict['CMP'][0] # 提取补语
                    r = words[index] + words[cmp_index] # 将谓词和补语连接起来形成动词(谓词)
                    if 'POB' in child_dict_list[cmp_index]: # 检查补语的子节点是否存在介宾关系（POB）
                        e2 = words[child_dict_list[cmp_index]['POB'][0]] # 如果存在介宾关系，则提取介宾关系对应的宾语
                        if e1.replace(' ', '') and e2.replace(' ', ''):
                            svos.append([e1, r, e2]) # 提取的主语（e1）、谓词（r）和宾语（e2）以语义三元组[e1, r, e2]的形式添加到svos列表中

        return svos

    '''
    三元组抽取主函数，旨在根据词性标注和依存解析信息从句子中提取主谓宾、主谓补和定语后置的动宾关系
    '''
    def ruler2(self, words, postags, child_dict_list, arcs):
        svos = [] # 用于保存抽取出的三元组
        for index in range(len(postags)): # 遍历句子中的每个词
            tmp = 1
            if tmp == 1: # 这个条件总是为真，因此这个条件是多余的...
                if postags[index]: # 如果语义角色标注（postags[index]）不为空，则使用语义角色标注的结果进行三元组抽取
                    child_dict = child_dict_list[index]
                    if 'SBV' in child_dict and 'VOB' in child_dict: # 查找主谓宾（SVO）三元组，通过检查是否存在主语（SBV）和宾语（VOB）作为子节点来确定
                        r = words[index] # 提取谓语(动词)
                        e1 = self.complete_e(words, postags, child_dict_list, child_dict['SBV'][0]) # 提取主语
                        e2 = self.complete_e(words, postags, child_dict_list, child_dict['VOB'][0]) # 提取宾语
                        if e1.replace(' ', '') and e2.replace(' ', ''): 
                            svos.append([e1, r, e2]) # 提取的主语（e1）、动词（r）和宾语（e2）以语义三元组[e1, r, e2]的形式添加到svos列表中，分别表示主语、动词和宾语

                    relation = arcs[index][0]
                    head = arcs[index][2]
                    if relation == 'ATT': # 检查当前词语的依存关系（relation）是否为“ATT”（定语后置），并且检查该词语的头部词语索引（head）
                        if 'VOB' in child_dict: # 进一步检查是否存在宾语（VOB）作为子节点
                            # 若存在，则使用complete_e方法来获取完整的实体词语，并构建谓词（r）
                            e1 = self.complete_e(words, postags, child_dict_list, head - 1) 
                            r = words[index]
                            e2 = self.complete_e(words, postags, child_dict_list, child_dict['VOB'][0])
                            # 构建一个临时字符串（temp_string），由谓词和宾语拼接而成。然后检查主语是否以该临时字符串开头，如果是，则从主语中移除该临时字符串的部分
                            temp_string = r + e2
                            if temp_string == e1[:len(temp_string)]:
                                e1 = e1[len(temp_string):]
                            # 检查临时字符串是否不在主语中，如果是，则将主语、谓词和宾语以语义三元组的形式添加到svos列表中
                            if temp_string not in e1:
                                if e1.replace(' ', '') and e2.replace(' ', ''):
                                    svos.append([e1, r, e2])


                    if 'SBV' in child_dict and 'CMP' in child_dict: # 通过查找主语（SBV）和补语（CMP）关系来检查主谓补（SVC）三元组是否存在
                        e1 = self.complete_e(words, postags, child_dict_list, child_dict['SBV'][0]) # 提取主语
                        cmp_index = child_dict['CMP'][0] # 提取补语
                        r = words[index] + words[cmp_index] # 将谓词和补语连接起来形成动词(谓词)
                        if 'POB' in child_dict_list[cmp_index]: # 检查补语的子节点是否存在介宾关系（POB）
                            e2 = self.complete_e(words, postags, child_dict_list, child_dict_list[cmp_index]['POB'][0]) # 如果存在介宾关系，则提取介宾关系对应的宾语
                            if e1.replace(' ', '') and e2.replace(' ', ''):
                                svos.append([e1, r, e2]) # 提取的主语（e1）、谓词（r）和宾语（e2）以语义三元组[e1, r, e2]的形式添加到svos列表中
        return svos

    '''
    对找出的主语或者宾语进行扩展
    通过递归调用自身，根据依存解析和词性标注信息，构建一个完整的实体词语，其中包括定语、动宾关系和主谓关系等相关部分
    '''
    def complete_e(self, words, postags, child_dict_list, word_index):
        child_dict = child_dict_list[word_index] # 获取词语索引对应的子节点字典
        prefix = '' # 存储前缀
        # 如果 child_dict 中存在 'ATT'（定语）关系，则通过循环遍历所有定语关系的子节点，使用递归调用 complete_e 方法获取每个子节点的完整实体词语，并将其添加到 prefix 中
        if 'ATT' in child_dict:
            for i in range(len(child_dict['ATT'])):
                prefix += self.complete_e(words, postags, child_dict_list, child_dict['ATT'][i])
        postfix = '' # 存储后缀
        # 如果 postags[word_index] 为 'v'（动词）
        if postags[word_index] == 'v':
            if 'VOB' in child_dict: # 如果 child_dict 中存在 'VOB'（动宾关系），则通过递归调用 complete_e 方法获取宾语的完整实体词语，并将其添加到 postfix 中
                postfix += self.complete_e(words, postags, child_dict_list, child_dict['VOB'][0])
            if 'SBV' in child_dict: # 如果 child_dict 中存在 'SBV'（主谓关系），则通过递归调用 complete_e 方法获取主语的完整实体词语，并将其与 prefix 进行拼接
                prefix = self.complete_e(words, postags, child_dict_list, child_dict['SBV'][0]) + prefix
        # 返回拼接后的字符串，由 prefix、words[word_index] 和 postfix 组成，表示完整的实体词语
        return prefix + words[word_index] + postfix

    '''
    程序主控函数，调用类方法依次实现分句、依存分析和三元组提取
    '''
    def triples_main(self, content):
        sentences = self.split_sents(content)
        svos = []
        for sentence in sentences:
            # print(sentence)
            words, postags, child_dict_list, arcs = self.parser_main(sentence)
            svo = self.ruler2(words, postags, child_dict_list, arcs)
            svos += svo

        return svos

# %%
# 新闻标题文本三元组抽取
def title_triples__ext():
    extractor_1 = SVOParser()
    target_file = open('./data/title_triples_data.txt', 'w', encoding='utf-8')
    with open('./data/title_data.txt','r',encoding='utf-8') as f:
        for line in f:
            svos = extractor_1.triples_main(line)
            for svo in svos:
                print(svo)
                target_file.write(str(svo) + '\n')
    target_file.close()
    print('新闻标题文本三元组提取完成')

# %%
# 正文文本三元组抽取
def text_triples__ext():
    extractor_2 = SVOParser()
    target_file = open('./data/text_triples_data.txt', 'w', encoding='utf-8')
    with open('./data/text_data.txt','r',encoding='utf-8') as f:
        for line in f:
            svos = extractor_2.triples_main(line)
            for svo in svos:
                print(svo)
                target_file.write(str(svo) + '\n')
    target_file.close()
    print('正文文本三元组提取完成')

# %%
# 标题和正文的三元组提取完毕后，将两个文件合并
# 将title_data和text_data合并
def merge_triples_data():

    with open('./data/text_triples_data.txt', 'r',encoding='utf-8') as file1:
        text1 = file1.read()

    with open('./data/title_triples_data.txt', 'r',encoding='utf-8') as file2:
        text2 = file2.read()

    merged_text = text1 + text2

    with open('./data/triples_data.txt', 'w',encoding='utf-8') as merged_file:
        merged_file.write(merged_text)
    
    print('合并完成')

# %%
# 分别执行标题文本和正文文本三元组抽取，抽取完毕后将两个文件合并
if __name__ == '__main__':
    title_triples__ext()
    text_triples__ext()
    merge_triples_data()
# Out:
# loaded model
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\dygraph\math_op_patch.py:277: UserWarning: The dtype of left and right variables are not the same, left dtype is paddle.int64, but right dtype is paddle.int32, the right dtype will convert to paddle.int64
#   .format(lhs_dtype, rhs_dtype, lhs_dtype))
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\framework.py:4006: DeprecationWarning: Op `cumsum` is executed through `append_op` under the dynamic mode, the corresponding API implementation needs to be upgraded to using `_C_ops` method.
#   DeprecationWarning,
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\dygraph\math_op_patch.py:277: UserWarning: The dtype of left and right variables are not the same, left dtype is paddle.int64, but right dtype is paddle.bool, the right dtype will convert to paddle.int64
#   .format(lhs_dtype, rhs_dtype, lhs_dtype))
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\framework.py:4006: DeprecationWarning: Op `fill_any_like` is executed through `append_op` under the dynamic mode, the corresponding API implementation needs to be upgraded to using `_C_ops` method.
#   DeprecationWarning,
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\dygraph\math_op_patch.py:277: UserWarning: The dtype of left and right variables are not the same, left dtype is paddle.float32, but right dtype is paddle.bool, the right dtype will convert to paddle.float32
#   .format(lhs_dtype, rhs_dtype, lhs_dtype))
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\dygraph\math_op_patch.py:277: UserWarning: The dtype of left and right variables are not the same, left dtype is paddle.float32, but right dtype is paddle.int32, the right dtype will convert to paddle.float32
#   .format(lhs_dtype, rhs_dtype, lhs_dtype))
# d:\Download_software\My_miniconda\envs\pytorch_py3.7\lib\site-packages\paddle\fluid\framework.py:4006: DeprecationWarning: Op `arg_max` is executed through `append_op` under the dynamic mode, the corresponding API implementation needs to be upgraded to using `_C_ops` method.
#   DeprecationWarning,
# ['377人', '失踪', '94人']
# ['暴雨灾害', '致', '150万余人受灾']
# ['暴雨', '致', '70人死亡']
# ['16省份', '遇', '洪涝灾害']
# ['洪涝灾害', '造成', '24省份受灾']
# ['洪涝灾害', '导致', '5793.1万人受灾']
# ['麦德姆', '致', '受灾人口1.83万']
# ['宜昌夷陵区', '遭', '特大洪灾']
# ['4省份', '发生', '洪涝灾害']
# ['洪灾', '致', '85人死亡']
# ['已', '致', '85人死亡']
# ['洪灾致85人死亡习近平李克强', '做出', '指示']
# ['洪涝灾情', '持续', '3人死亡']
# ['已', '致', '内蒙辽宁']
# ['东北华南', '遭受', '54人']
# ['东北局部地区', '遭受', '洪涝灾害']
# ['东北局部地区', '遭受', '洪涝灾害']
# ['东北局部地区遭受洪涝灾害', '造成', '1人死亡']
# ['洪涝灾害', '致', '85人死亡']
# ['已', '致', '85人死亡']
# ['强降雨', '致', '洪涝灾害']
# ['两部委', '补助', '资金']
# ['两部门', '启动', '四级应急响应']
# ['两部门', '启动', 'Ⅳ级应急响应']
# ['两部门', '启动', '四级救灾应急响应']
# ['两部门', '启动', 'Ⅳ级应急响应']
# ['两部门', '启动', 'Ⅳ级救灾应急响应']
# ['两部门', '启动', 'Ⅳ级救灾应急响应']
# ['两部门', '启动', '国家四级应急响应']
# ['两部门', '启动', '四级救灾应急响应']
# ['两部门', '启动', '国家四级救灾应急响应']
# ['中国', '遭', '暴雨']
# ['中国遭暴雨', '造成', '6人失踪']
# ['28个省份', '遭受', '洪涝灾害']
# ['受灾人口', '达', '1.4亿人']
# ['28个省份', '遭受', '洪灾']
# ['28个省份', '遭受', '洪灾']
# ['1.37亿人', '遭受', '558人失踪']
# ['28省份', '遭', '928人']
# ['28省区市', '遭受', '742人洪涝灾害死亡']
# ['降水', '造成', '洪涝滑坡灾害']
# ['中央财政', '拨', '3亿元']
# ['堤防', '出现', '险情']
# ['中国', '已有', '377人死亡']
# ['中国', '有', '392人死亡']
# ['受灾人口', '达', '6870万']
# ['受灾人口', '达', '6870万']
# ['99条河流', '发生', '超警洪水']
# ['中国八省逾亿亩农作物', '遭受', '洪涝灾害']
# ['北方三省区', '遭遇', '2人失踪']
# ['暴雨洪灾', '致', '失踪']
# ['中国南方', '遭受', '暴雨灾害']
# ['中国南方遭受暴雨灾害', '导致', '人员伤亡']
# ['中国南方', '遭受', '洪灾']
# ['中国南方', '遭', '暴雨袭击']
# ['中国南方暴雨', '加剧', '洪涝灾害']
# ['中国南方暴雨加剧洪涝灾害', '致', '亡20']
# ['中国南方暴雨灾害', '造成', '15人死亡']
# ['洪涝灾害', '致', '新一轮强降雨将来袭']
# ['洪涝灾害', '造成', '受灾']
# ['强降雨过程', '持续', '洪涝灾害']
# ['3000万人', '遭', '洪灾']
# ['3000万人', '遭', '洪灾']
# ['近期暴雨', '造成', '55人死亡']
# ['中国南方', '遭', '袭击']
# ['等鲁滇晋', '出现', '暴雨灾害']
# ['突降暴雨', '引发', '洪涝灾害']
# ['水灾洪水', '盘踞', '东北']
# ['高温', '离', '江南']
# ['多省区', '遭遇', '高温范围缩小']
# ['多省区', '遭遇', '高温范围缩小']
# ['多省市', '遭受', '暴雨']
# ['中国洪涝', '致', '1.13亿人受灾']
# ['经济损失', '达', '1422亿']
# ['洪涝灾害', '致', '人死亡']
# ['中国红十字会总会', '提供', '救助']
# ['中国红十字会', '调拨', '80万元物资']
# ['中国红十字总会', '提供', '救助']
# ['赈济家庭箱', '驰援', '洪涝灾区']
# ['中国', '启动', '国家救灾应急响应']
# ['局地', '出现', '洪涝灾情']
# ['云南丽江山洪灾害', '致', '人失踪']
# ['云南云龙县', '遭受', '洪涝灾害']
# ['云南保山', '搜救', '山洪失踪者']
# ['等文山地', '遭受', '2人洪涝灾害死亡']
# ['洪涝灾害', '致', '95万余人受灾']
# ['山洪泥石流灾害', '致', '1人死亡']
# ['多地', '发生', '洪涝灾害']
# ['多地发生洪涝灾害', '造成', '7人死亡']
# ['云南宣威', '遭受', '洪涝灾害']
# ['洪灾死亡人数', '增至', '28人失踪']
# ['云南局地强降雨', '引发', '洪涝灾害']
# ['云南局地', '遭', '200余万经济损失']
# ['云南巧家洪灾', '致', '19人遇难']
# ['云南巧家洪灾', '致', '19人遇难']
# ['洪涝灾害', '致', '13人死亡']
# ['已', '致', '13人死亡']
# ['洪涝灾害死亡人数', '上升至', '17人']
# ['云南强降雨', '引发', '23人等泥石流灾害死亡']
# ['彝良震灾区', '遭遇', '洪涝灾害']
# ['彝良震灾区', '遭遇', '洪涝灾害']
# ['云南昭通', '发生', '洪涝灾害']
# ['云南昭通发生洪涝灾害', '致', '5人死亡']
# ['云南普洱临沧', '遭受', '洪涝灾害']
# ['等普洱地', '遭受', '洪涝灾害']
# ['云南景谷县', '发生', '洪涝灾害']
# ['云南景谷泥石流', '致', '10人失踪']
# ['云南暴雨', '引发', '等滑坡灾害致13人死33人']
# ['等滑坡灾害', '致', '13人死33人']
# ['13人', '死', '33人']
# ['洪涝灾害', '致', '死4伤']
# ['受伤人员', '增至', '5人']
# ['受伤人员', '增至', '5人']
# ['云南', '发布', '山洪灾害预警']
# ['洪涝灾害', '致', '万人受灾']
# ['洪涝灾害', '造成', '9人失踪']
# ['云南盈江', '发生', '洪涝泥石流灾害']
# ['云南盈江', '发生', '洪涝泥石流灾害']
# ['云南盈江洪涝', '致', '两万八千余人受灾']
# ['云南盐津', '发生', '洪涝灾害']
# ['云南盐津发生洪涝灾害', '致', '5人失踪']
# ['洪涝灾害', '致', '2人死亡']
# ['部分地区', '遭受', '400余万经济损失']
# ['地', '遭', '2人万人2.9受灾失踪']
# ['云南', '发生', '洪涝']
# ['云南发生洪涝', '致', '5伤']
# ['云南', '遭受', '洪涝灾害']
# ['部分地区', '发生', '1人死亡灾害']
# ['部分地区', '遭受', '滑坡灾害']
# ['部分地区遭受滑坡灾害', '造成', '3人死亡']
# ['部分地区', '遭受', '洪涝灾害']
# ['云南鱼洞', '突发', '断水断电']
# ['洪灾', '致', '2人失踪']
# ['特大山洪泥石流灾害遇难者', '增至', '10人']
# ['云南麻栗坡', '突发', '洪涝灾害']
# ['79人', '经济损失', '137亿元']
# ['1643个县', '遭', '448人死亡']
# ['万人受灾', '损失', '43亿元']
# ['受灾人口', '升至', '5985万人']
# ['30省区市', '遭', '洪涝灾害']
# ['中国7677万人', '遭', '洪灾']
# ['受灾人口', '超', '2000万']
# ['2719万人', '遭受', '洪涝灾害']
# ['28省份', '遭受', '洪涝灾害']
# ['洪灾', '造成', '1454人死']
# ['中央', '拨', '救灾']
# ['橙色预警', '发布', '抗洪能力超18年前']
# ['等佳木斯地', '发生', '27万人受灾万人转移']
# ['等张家口', '遭受', '2人死亡']
# ['12省份', '发生', '洪涝灾害']
# ['全国', '有', '22个省份遭受洪涝灾害']
# ['22个省份', '遭受', '洪涝灾害']
# ['1508县', '遭受', '洪灾']
# ['万人', '遭', '洪灾']
# ['全国', '已有', '地暴雨持续']
# ['1192县', '遭受', '洪涝灾害']
# ['1192县', '遭受', '洪涝灾害']
# ['400万元', '援助', '黔']
# ['等湘省份', '遭受', '洪涝灾害']
# ['旗县', '遭', '洪灾']
# ['等呼伦贝尔', '遭受', '洪涝灾害']
# ['内蒙古固阳县', '遭受', '洪涝灾害']
# ['内蒙古固阳县遭受洪涝灾害', '导致', '1人溺水']
# ['内蒙古暴雨洪灾', '致', '19人遇难']
# ['官方', '启动', '四级救灾响应']
# ['内蒙古武川县', '遭受', '洪涝灾害']
# ['甘肃局地', '遭受', '洪涝灾害']
# ['内蒙古红花尔基水库泄洪', '造成', '近4千人受灾']
# ['内蒙古赤峰', '遭受', '洪涝灾害']
# ['内蒙古黑龙江局地', '遭受', '洪涝灾害']
# ['内蒙古黑龙江局地', '遭受', '洪涝灾害']
# ['内蒙古黑龙江部分地区', '遭受', '3人洪涝灾害失踪']
# ['内蒙赤峰阿鲁科尔沁旗', '遭受', '洪涝灾害']
# ['内蒙黑龙江局地', '遭', '洪涝灾害']
# ['减灾委', '启动', 'Ⅳ级救灾响应']
# ['减灾委民政部', '启动', '四级应急响应']
# ['暴雨', '致', '380余万人受灾']
# ['部分地区', '遭', '1人死亡']
# ['华北西北', '发生', '风雹灾害']
# ['华北西北局部', '遭', '洪涝灾害']
# ['18人', '死', '4']
# ['洪涝灾害', '致', '1人死亡']
# ['部分地区', '发生', '洪涝风雹灾害']
# ['洪涝灾情', '致', '经济损失']
# ['广东经济损失', '超', '8千万元']
# ['华南局地', '遭', '洪涝风雹灾害']
# ['洪涝灾害', '致', '等道路']
# ['洪涝灾害', '致', '等道路']
# ['洪灾', '造成', '民政部调运物资']
# ['4省份', '遭受', '洪涝风雹灾害']
# ['4省份', '遭受', '洪涝风雹灾害']
# ['洪涝灾害', '造成', '3人死亡']
# ['6省份', '发生', '1死灾害']
# ['7省', '遭受', '3人失踪']
# ['南方六省', '遭受', '风雹灾害']
# ['南方地区', '遭', '袭击']
# ['专家', '称', '重现98年洪灾']
# ['多个省份', '遭受', '洪涝灾害']
# ['多个省份遭受洪涝灾害', '造成', '12人死亡']
# ['南方', '抗击', '洪涝灾害']
# ['南方', '遭', '2人洪涝灾害死亡']
# ['降雨', '引发', '致1人失踪灾害']
# ['多省份', '遭受', '洪涝灾害']
# ['多省份', '遭受', '洪涝灾害']
# ['多省大雨', '导致', '洪涝风雹灾害']
# ['多省大雨', '导致', '洪涝风雹灾害']
# ['多省市', '遭受', '洪涝灾害']
# ['多省市遭受洪涝灾害', '造成', '2人失踪']
# ['南方局地', '出现', '到大雨引发洪涝灾害']
# ['到大雨', '引发', '洪涝灾害']
# ['南方局地', '遭受', '洪涝灾害']
# ['致多省份', '遇', '洪灾']
# ['南方暴雨', '造成', '27人死亡']
# ['洪涝灾害', '致', '进入关键期']
# ['洪涝灾害', '致', '39人死亡']
# ['洪涝灾害', '致', '11人死亡']
# ['南方', '遭受', '级应急响应']
# ['部分地区', '发生', '洪涝灾害']
# ['直接经济损失', '超', '66亿元']
# ['部分地区', '遭受', '洪涝风雹灾害']
# ['部分地区', '遭受', '3人溺水']
# ['部分地区', '遭受', '14.7万人受灾']
# ['部分地区', '遭', '1人洪涝风雹灾害溺水']
# ['部分地区', '遭', '洪涝风雹灾害']
# ['部分地区', '遭', '5人亡']
# ['部分地区', '遭', '洪涝灾害']
# ['1人', '雷击', '死亡']
# ['受强降雨', '影响', '多地发生洪涝灾害']
# ['多地', '发生', '洪涝灾害']
# ['死亡人数', '增至', '16人']
# ['局部', '遭受', '洪涝灾害']
# ['局部', '遭受', '洪涝灾害']
# ['暴雨', '发生', '洪灾']
# ['暴雨发生洪灾', '致', '22.6万人转移']
# ['洪灾', '致', '13人丧生']
# ['吉林洪灾', '致', '失踪']
# ['灾区', '遭', '强降雨']
# ['吉林洪灾死67失踪', '有', '39座水库超限']
# ['山洪灾害遇难者', '增至', '14人']
# ['吉林省洪灾', '致', '36失踪']
# ['吉林', '遭受', '洪涝灾害']
# ['洪水', '致', '512万人受灾']
# ['洪灾', '致', '122人死亡']
# ['吉黑部分地区', '遭受', '2.8亿元']
# ['嘉陵江洪水', '造成', '35.64万人受灾']
# ['经济损失', '达', '164.4亿']
# ['四川7・9暴雨', '造成', '58人死亡']
# ['泥石流灾害', '致', '失踪']
# ['28人', '发', '暴雨']
# ['气象台', '发', '暴雨']
# ['局部暴雨', '引发', '致']
# ['等凉山', '发生', '洪涝泥石流灾害']
# ['4500余人', '投入', '抗洪']
# ['四川', '遭受', '洪涝灾害']
# ['四川遭受洪涝灾害', '致', '68人死亡']
# ['四川', '遭受', '洪涝灾害']
# ['失踪人数', '超', '两百']
# ['宜宾乐山', '遭受', '洪涝灾害']
# ['宜宾乐山遭受洪涝灾害', '造成', '2人失踪']
# ['四川宣汉', '造成', '142户农房垮塌']
# ['四川小金', '发生', '泥石流灾害']
# ['洪涝灾害', '致', '1.2万人受灾']
# ['四川屏山', '遭', '洪涝灾害']
# ['四川屏山', '遭', '洪涝灾害']
# ['泥石流灾害', '造成', '13人死亡']
# ['112万余人', '遭受', '3人失踪']
# ['四川德阳震灾区', '遭', '山洪袭击']
# ['四川暴雨洪灾', '致', '200余万人受灾']
# ['四川暴雨洪灾', '致', '200余万人受灾']
# ['洪涝灾害', '致', '2死']
# ['四川洪灾', '致', '19人死亡']
# ['经济损失', '逾', '百亿元']
# ['四川洪灾', '造成', '26人死亡']
# ['四川渠县洪灾', '造成', '水源污染']
# ['四川甘洛凉红电站洪灾', '证实', '6人遇难']
# ['四川甘洛', '遇', '4人洪灾遇难']
# ['山洪灾害', '致', '24人死亡']
# ['山洪灾害致24人死亡', '有', '1人失联']
# ['四川筠连县', '遭受', '洪涝灾害']
# ['特大洪灾', '捐赠', '100万元物资']
# ['等达州地', '遭受', '洪涝灾害']
# ['等阿坝地', '遭受', '19.1万人受灾']
# ['等阿坝地', '遭受', '1人洪涝灾害死亡']
# ['贵州甘肃青海', '遭受', '洪涝灾害']
# ['损失', '逾', '2.45亿元']
# ['洪水灾害', '致', '9人死亡']
# ['直接损失', '达', '63亿']
# ['等阿坝地', '遭受', '洪涝灾害']
# ['四川', '遭遇', '应急启动']
# ['部分地区', '遭受', '受灾']
# ['部分地方', '发生', '洪涝灾情']
# ['威远山体滑坡', '致', '6死']
# ['四川陕西', '遭', '暴雨灾害']
# ['四川陕西', '遭', '暴雨灾害']
# ['四川陕西遭暴雨灾害官方', '启动', '救灾应急响应']
# ['四川陕西', '遭', '洪涝灾害']
# ['泥石流灾害', '致', '12人失踪']
# ['四川青川受灾', '造成', '4死失踪']
# ['洪涝灾害', '造成', '返贫']
# ['洪涝风雹灾害', '致', '102人死亡']
# ['启动', '应对', '山西灾害']
# ['启动', '应对', '洪涝灾情']
# ['国家防总', '介绍', '防汛情况']
# ['1508县', '遭受', '洪涝灾害']
# ['国家防总派工作组', '赴', '湘黔']
# ['国家防总', '部署', '重庆贵州强降雨应对']
# ['2043万人', '遭受', '洪涝灾害']
# ['受灾人口', '超', '1490万']
# ['洪涝灾害', '致', '91人遇难']
# ['水库', '无', '垮坝']
# ['广西', '启动', 'IV级应急响应']
# ['多次暴洪', '造成', '82.75亿元']
# ['灾害', '致', '22人死亡']
# ['受灾群众', '补助', '十元']
# ['安庆池州黄山', '发生', '洪涝灾害']
# ['5市', '遭遇', '洪涝灾害']
# ['5市', '遭遇', '洪涝灾害']
# ['发生灾害', '致', '5死失踪']
# ['洪涝灾害', '致', '3万余人受灾']
# ['洪涝', '致', '10人死']
# ['安徽河南局地', '遭', '洪涝灾害']
# ['直接经济损失', '逾', '亿元']
# ['洪涝灾害', '致', '27人死亡']
# ['洪涝灾害', '致', '160.8万人受灾']
# ['洪涝灾害', '致', '160.8万人受灾']
# ['洪涝灾害致160.8万人受灾两部门', '调拨', '救灾物资']
# ['安徽洪灾', '致', '418死失踪']
# ['200万人', '遭受', '安全转移']
# ['安徽', '遭', '袭击']
# ['部分地区', '出现', '洪涝灾害']
# ['洪涝灾害', '致', '1人死亡']
# ['9人', '失踪', '4人']
# ['官方', '启动', '国家四级救灾应急响应']
# ['官方启动国家四级救灾应急响应', '应对', '重庆洪灾']
# ['官方', '启', '国家四级救灾应急响应']
# ['官方启国家四级救灾应急响应', '指导', '洪灾']
# ['官方', '启', '国家四级救灾应急响应']
# ['官方启国家四级救灾应急响应', '指导', '安徽洪灾']
# ['洪涝灾害', '致', '15人死亡']
# ['山东17县', '发生', '洪涝灾害']
# ['19县市', '遭受', '107万人受灾']
# ['直接经济损失', '逾', '7亿元']
# ['山东', '加紧', '灾后重建']
# ['多地', '发生', '洪涝灾害']
# ['多地', '发生', '洪涝灾害']
# ['等东营地', '遭受', '洪涝灾害']
# ['山东普降大雨', '引', '洪涝灾害']
# ['部分地区', '发生', '洪涝灾害']
# ['等滨州地', '遭受', '洪涝灾害']
# ['遭受洪涝灾害局地', '降大', '暴雨']
# ['泥石流灾害', '致', '44人死亡']
# ['28个县', '遭受', '22万人受灾']
# ['山西8市', '遭受', '7人死亡']
# ['等吕梁', '遭受', '3人5人洪涝灾害死亡失踪']
# ['山西山东局地', '遭受', '洪灾']
# ['洪水', '冲走', '村民']
# ['洪水冲走村民', '致', '1死']
# ['8市', '遭受', '1人失踪']
# ['等阳泉', '遭受', '洪涝灾害']
# ['地', '遭受', '洪涝灾害']
# ['陕西局地', '遭', '风雹灾害']
# ['洪涝灾害', '致', '38.5万人受灾']
# ['洪涝灾害', '致', '38万人受灾']
# ['洪涝灾害', '致', '37人死亡']
# ['持续发展', '造成', '14人死']
# ['广东暴雨', '致', '级救灾应急响应']
# ['广东暴雨', '致', '20人遇难']
# ['广东洪灾经济损失', '逾', '7人']
# ['官方', '启动', '国家级救灾响应']
# ['广东福建', '遭受', '洪涝灾害']
# ['洪灾遇难人数', '增至', '70人']
# ['山洪灾害', '致', '66人死亡']
# ['广东茂名', '洪灾', '75人']
# ['死亡', '增至', '23人']
# ['增至23人灾害', '失踪', '36人']
# ['排洪调度', '不当', '质疑']
# ['182万人', '遭', '洪灾']
# ['182万人', '遭', '洪灾']
# ['7.7万人', '遭受', '洪灾']
# ['广西大部地区普降大雨', '现', '洪涝受灾']
# ['全区', '逾', '8万人']
# ['广西局地', '遭受', '洪涝灾害']
# ['广西局地', '遭', '洪涝灾害']
# ['7900余人', '受灾', '2200余房损坏']
# ['广西局部', '遭', '洪涝风雹灾害']
# ['强降雨', '引发', '等洪涝灾害']
# ['应急管理部工作组', '赶赴', '灾区']
# ['洪涝灾害', '造成', '直接经济损失超3亿元']
# ['洪涝灾害造成直接经济损失超3亿元', '逾', '32万人受灾']
# ['直接经济损失', '超', '3亿元']
# ['广西洪灾两部门', '启动', '国家级救灾应急响应']
# ['广西洪灾死亡人数', '升至', '18人']
# ['广西洪灾死亡人数', '升至', '18人']
# ['等贺州地', '遭受', '暴雨灾害']
# ['等贺州地遭受暴雨灾害', '致', '1死']
# ['广西', '遭受', '强降雨天气侵袭']
# ['现', '致', '6人死亡']
# ['广西', '遭受', '洪涝灾害']
# ['部分地区', '遭受', '3人21.5万人受灾灾害死亡']
# ['本轮暴雨灾害', '造成', '614万人受灾']
# ['张家口', '遭', '风暴灾害']
# ['直接经济损失', '逾', '9000万']
# ['强降雨', '带来', '如此大考']
# ['强降雨', '袭', '473座水库溢洪']
# ['湖南', '致', '53万余人受灾']
# ['42万人', '遭', '洪灾图']
# ['强降雨', '致', '南方六省发生洪涝灾害']
# ['南方六省', '发生', '洪涝灾害']
# ['强降雨', '致', '多条河流出现大洪水']
# ['多条河流', '出现', '大洪水']
# ['强降雨', '致', '四川盆地遭洪涝灾害']
# ['强降雨', '致', '四川盆地遭洪涝灾害']
# ['四川盆地', '遭', '洪涝灾害']
# ['川陕豫', '遭', '洪涝灾害']
# ['强降雨', '致', '出现10人死亡灾害']
# ['强降雨', '致', '洪涝灾害']
# ['强降雨', '致', '22.9万人受灾']
# ['强降雨', '致', '22.9万人受灾']
# ['现', '致', '失踪']
# ['死亡人数', '升至', '63人']
# ['13人', '确认', '死亡']
# ['死亡人数', '上升至', '76人']
# ['洪灾死亡人数', '升至', '54人']
# ['洪灾死亡人数', '升至', '54人']
# ['发生洪涝风雹灾害', '致', '3死']
# ['强降雨', '引发', '洪涝灾害']
# ['强降雨', '引发', '洪涝灾害']
# ['新一轮暴雨', '致', '2.6万人受灾']
# ['死亡', '超', '百人']
# ['新安江泄洪', '造成', '影响']
# ['13个县市', '发生', '暴雨灾害']
# ['13个县市', '发生', '暴雨灾害']
# ['县市', '遭受', '暴雨灾害']
# ['新疆伊犁', '发生', '洪涝灾害']
# ['泥石流灾害', '致', '1.43亿损失']
# ['洪水灾害', '造成', '4人死亡']
# ['新疆兵团农场', '遇', '最大洪灾救灾进行']
# ['部分地区', '发生', '洪涝灾害']
# ['洪涝灾害', '造成', '1人死亡']
# ['新疆南疆局地', '遭受', '4万人死亡']
# ['特大洪灾', '致', '455人困']
# ['洪水灾害', '造成', '7人死亡']
# ['洪灾经济损失', '逾', '2.7亿']
# ['新疆吐鲁番', '遭遇', '罕见洪灾']
# ['直接经济损失', '超', '2.7亿']
# ['和田地区皮山县', '遭受', '洪涝灾害']
# ['部分县普降大', '到', '暴雨']
# ['部分县普降大到暴雨', '发生', '洪涝灾害']
# ['等地', '遭', '洪涝灾害']
# ['新疆尼勒克', '遭遇', '洪水泥石流']
# ['新疆局地', '发生', '洪涝灾害']
# ['新疆布尔津县', '受', '融雪性洪水侵袭']
# ['新疆布尔津县', '遭', '洪涝灾害']
# ['1.6亿', '投入', '5万人']
# ['困人员', '实现', '转移']
# ['特大洪灾', '致', '千余人困']
# ['新疆新湖', '暴发', '洪灾']
# ['损失', '过', '千万元']
# ['洪涝灾害', '致', '万人9.9受灾']
# ['部分地区', '遭受', '洪涝风雹灾害']
# ['部分地区遭受洪涝风雹灾害', '致', '2500余人受灾']
# ['晋川滇陕局地', '遭受', '1人失踪']
# ['暴洪泥石流', '致', '12万余人受灾']
# ['暴洪灾害', '致', '损毁']
# ['损失', '超', '3亿元']
# ['两部委', '启动', '级救灾响应']
# ['3人死亡经济损失', '逾', '1亿']
# ['洪水', '造成', '受灾']
# ['暴雨', '导致', '启动防汛级响应']
# ['暴雨', '致', '83座桥梁损毁']
# ['洪涝', '致', '8人失踪']
# ['洪涝', '致', '2人遇难']
# ['经济损失', '达', '9800万']
# ['暴雨', '致', '24万人受灾']
# ['暴雨', '致', '143.2万人受灾']
# ['洪灾', '致', '5人死亡']
# ['财政', '拨付', '5500万']
# ['财政', '拨付', '5500万']
# ['暴雨', '致', '76万人受灾']
# ['吉林省', '采取', '十项措施']
# ['暴雨', '袭', '18人死亡']
# ['400余万人', '受', '洪灾']
# ['民政部', '调运', '救灾物资']
# ['民政部', '启动', 'Ⅳ级救灾应急响应']
# ['民政部', '启动', '四级响应']
# ['民政部', '启动', '救灾响应']
# ['暴雨灾害', '致', '37人死亡']
# ['近日暴雨', '造成', '1719万人受灾']
# ['洪涝灾害', '致', '9人死亡']
# ['洪涝灾害', '造成', '31人死亡']
# ['洪涝灾害', '致', '200余万人受灾']
# ['暴雨', '致', '6人死']
# ['暴雨', '造成', '50人死亡']
# ['暴雨洪灾', '致', '22人失踪']
# ['73.4万人', '受灾', '5人死亡']
# ['江南江汉局地', '遭', '洪涝灾害']
# ['村庄', '受淹', '房屋']
# ['洪涝灾害', '造成', '157万余人受灾']
# ['江南西南', '遭受', '洪涝风雹灾害']
# ['1人', '雷击', '死亡']
# ['江南西南局地', '遭受', '洪涝风雹灾害']
# ['4省', '遭', '洪涝灾害']
# ['4省', '遭', '洪涝灾害']
# ['江苏暴雨灾害', '造成', '2.8万人转移']
# ['8市', '发生', '暴雨灾害']
# ['国家', '启动', '洪涝灾害']
# ['紧急', '启动', '洪涝灾害']
# ['52万余人', '遭受', '上千房屋冲毁']
# ['洪灾', '致', '人2死']
# ['损失', '超', '500亿']
# ['修水洪灾', '致', '1152间房屋倒塌']
# ['江西', '遭', '袭击']
# ['暴雨', '袭击', '洪涝灾害']
# ['等九江地', '遭受', '洪涝灾害']
# ['江西', '发布', '洪水预警']
# ['洪涝', '致', '受灾']
# ['江西安福暴雨', '致', '漫民房图']
# ['江西广西', '遭', '洪涝灾害']
# ['江西德兴市', '遭受', '严重洪灾']
# ['强降雨', '引发', '洪涝灾害']
# ['洪灾人数', '升至', '113万民政部']
# ['受灾人数', '上升至', '20.2万']
# ['江西洪灾', '致', '4人死亡']
# ['江西湖南两省局地', '遭受', '13.5万人受灾图']
# ['逾8万人大暴雨', '受', '洪涝灾害']
# ['江西', '遭受', '洪涝灾害']
# ['汪洋', '视察', '吉林防汛']
# ['多县市', '遭受', '四人洪涝灾害死亡']
# ['河北吉林局地', '遭', '洪涝灾害']
# ['直接经济损失', '逾', '5亿']
# ['5市', '遭受', '224间房屋倒塌']
# ['19县市', '遭受', '74.6万人洪涝灾害受灾']
# ['河北局地', '遭受', '洪涝灾害']
# ['河北山西', '遭受', '洪涝灾害']
# ['河北山西', '遭受', '洪涝灾害']
# ['受灾损失', '过', '两亿']
# ['河北强降雨', '引发', '洪涝灾害']
# ['河北强降雨引发洪涝灾害', '致', '两人遇难']
# ['河北易县', '受', '洪灾影响']
# ['91个行政村', '恢复', '电力供应']
# ['河北河南两地', '遭受', '洪涝风雹灾害']
# ['洪涝灾害', '致', '105人死亡']
# ['河北洪灾', '致', '32死']
# ['已', '致', '32死']
# ['救灾人员', '进入', '受困村镇']
# ['涞源洪灾', '致', '3个自然村夷为平地']
# ['五市', '遭受', '3人死亡']
# ['河北', '遭受', '洪涝灾害']
# ['部分地区', '遭受', '洪涝灾害']
# ['洪涝灾害', '致', '10.4万人受灾']
# ['13市', '遭', '洪涝灾害']
# ['13市遭洪涝灾害', '造成', '10人死亡']
# ['河南468个乡镇', '遭受', '洪涝灾害']
# ['经济损失', '超', '亿元']
# ['部分地区', '遭受', '洪涝灾害']
# ['河南洪灾', '夺', '命损百亿']
# ['暴雨', '引发', '4人山洪灾害死亡']
# ['洪涝灾害', '致', '52人死亡']
# ['河南', '遭受', '洪涝灾害']
# ['河南', '遭', '洪涝灾害']
# ['河南', '遭', '洪涝灾害']
# ['直接经济损失', '达', '5.42亿']
# ['河南鹤壁局', '发生', '洪涝灾害']
# ['经济损失', '近', '6000万']
# ['洪水', '造成', '180万人受灾']
# ['抚顺死亡人数', '升至', '63人']
# ['洪涝灾害', '致', '341万人受灾']
# ['洪涝灾害', '致', '人遇难']
# ['洪涝灾害', '导致', '521.3万人受灾']
# ['洪涝灾害', '致', '237人死亡']
# ['洪涝灾害', '致', '111人死亡']
# ['洪涝灾害', '影响', '347人失踪']
# ['洪涝灾害', '致', '抢险']
# ['洪涝灾害', '致', '593亿']
# ['洪涝灾害', '致', '全省805']
# ['洪涝灾害', '致', '百万人受灾']
# ['医疗秩序', '受', '影响']
# ['洪涝灾害', '致', '7人死亡']
# ['洪涝灾害', '致', '江西启动救灾四级应急响应']
# ['洪涝灾害', '造成', '3人失踪']
# ['洪涝灾害', '造成', '受灾损失2751.6亿']
# ['洪涝灾害', '造成', '受灾']
# ['三峡', '迎新', '一轮洪峰']
# ['洪涝', '致', '4.1万人受灾']
# ['洪涝', '致', '2人遇难']
# ['洪涝', '致', '超警戒']
# ['洪涝', '致', '江西76.4万人受灾']
# ['致江西', '逾', '7人']
# ['洪涝致赣', '逾', '5.8万人抗洪图']
# ['强降雨', '致', '15']
# ['洪灾', '造成', '严重损失']
# ['四川广安', '逾', '25万人受灾']
# ['四川广安', '逾', '25万人受灾']
# ['洪灾', '致', '3人失踪']
# ['洪灾', '致', '转移']
# ['洪灾', '致', '转移']
# ['洪灾', '致', '4人死亡']
# ['1人', '失踪', '20.2万人']
# ['12万人', '受', '洪灾']
# ['浙江安徽新疆', '遭受', '洪涝灾害']
# ['受灾人数', '超', '9万']
# ['国家', '启动', '四级应急响应']
# ['浙江局部地区', '遭', '洪涝灾害']
# ['浙江广东云南', '遭受', '洪涝灾害']
# ['浙江广东云南遭受洪涝灾害', '造成', '3人失踪']
# ['浙江贵州局地', '遭受', '洪涝灾害']
# ['暴雨洪涝两部门', '启动', '国家级救灾应急响应']
# ['2858.5万人', '遭受', '暴雨灾害']
# ['地', '遭受', '洪涝灾害']
# ['海南', '遭', '暴雨灾害']
# ['民政部', '启动', '四级救灾响应']
# ['海南局地', '遭受', '5千余万元']
# ['洪涝灾害', '造成', '13万人转移']
# ['16县市区', '遭', '暴雨']
# ['27县市', '遭受', '逾133万人受灾']
# ['38万余人', '遭', '暴雨']
# ['一夜经济损失', '逾', '2亿']
# ['61万余人', '遭', '洪涝灾害']
# ['直接经济损失', '逾', '7亿']
# ['湖北启动救灾应急三级响应', '应对', '暴雨灾害']
# ['洪涝灾害', '致', '23人死亡']
# ['已', '致', '23人死亡']
# ['洪涝灾害', '致', '1死']
# ['湖北宜昌洪涝灾害', '致', '18万人受灾']
# ['湖北局地', '遭受', '1人10.2万人受灾灾害死亡']
# ['湖北暴雨灾害', '造成', '32人死亡']
# ['洪灾', '损失', '4100多万']
# ['湖北沙洋', '开展', '灾后自救']
# ['洪涝灾害', '致', '14人死亡']
# ['国家', '启动', '四级应急响应']
# ['洪涝灾害', '致', '部分房屋倒损']
# ['92个A级景区', '受', '损毁']
# ['洪涝灾害', '造成', '700万人受灾']
# ['16县市', '遭受', '3人死亡']
# ['70万人', '遭', '洪灾']
# ['湖北', '遭受', '暴雨']
# ['205万人', '遭受', '洪灾']
# ['湖南', '遭', '3人死亡']
# ['部分地区', '遭', '洪涝灾害']
# ['洪涝灾害', '逾', '十万人受灾']
# ['多地', '遭受', '3人失踪']
# ['湖南', '遭受', '洪涝灾害']
# ['多地', '遭受', '洪涝灾害']
# ['1人', '埋', '死亡']
# ['湖南安化', '发生', '特大暴雨山洪灾害']
# ['湖南安化发生特大暴雨山洪灾害', '导致', '5死失踪']
# ['湖南局地', '遭受', '洪涝灾害']
# ['湖南局部地区', '遭', '洪涝灾害']
# ['湖南暴雨', '引发', '地质灾害']
# ['湖南暴雨引发地质灾害', '造成', '7人死亡']
# ['洪涝灾害死亡人数', '升至', '36人']
# ['湖南洪灾死亡人数', '升至', '16人']
# ['多省', '遭受', '逾千万人洪涝灾害受灾']
# ['等湖北省', '遇', '洪涝灾害']
# ['暴雨周强', '要求', '防御地质灾害']
# ['湖南', '遭受', '8人']
# ['受灾人口', '达', '200多万']
# ['湖南', '遭', '强降雨坏话出现洪涝灾情']
# ['强降雨坏话', '出现', '洪涝灾情']
# ['强降雨娄底', '出现', '洪涝灾情']
# ['暴雨民政部', '启动', '救灾响应']
# ['等娄底', '遭', '洪涝灾害']
# ['湖南青海局地', '遭受', '洪涝灾害']
# ['洪涝灾害', '致', '41人亡']
# ['特大暴雨', '引发', '山洪']
# ['特大暴雨', '引发', '山洪']
# ['甘肃3市州强降雨', '引发', '洪涝冰雹灾害']
# ['甘肃3市州强降雨引发洪涝冰雹灾害', '造成', '7死26伤']
# ['暴洪灾害', '致', '8人失踪']
# ['暴洪灾害', '致', '8人失踪']
# ['遇难人数', '增至', '13人']
# ['等兰州地', '遭受', '洪涝灾害']
# ['甘肃天水市', '遭受', '4人暴雨遇难']
# ['暴洪灾害', '导致', '24人死亡']
# ['暴洪灾害', '致', '22人死亡']
# ['暴洪灾害', '致', '22人死亡']
# ['甘肃宕昌县', '遭受', '1人洪涝灾害致4.5万人受灾死亡']
# ['遭泥石流灾害', '致', '1人死亡']
# ['等定西地', '遭受', '洪涝灾害']
# ['等定西地', '遭受', '1人万人2受灾失踪']
# ['甘肃局地', '发生', '8.7万人受灾灾害']
# ['局部地方', '遭', '洪涝灾害']
# ['7县市', '遭', '洪涝灾害']
# ['甘肃正宁县洪灾', '致', '1人遇难']
# ['甘肃正宁县', '遭受', '洪涝灾害']
# ['甘肃正宁县遭受洪涝灾害', '造成', '1人死亡']
# ['洪涝灾害', '致', '4人死亡']
# ['洪涝灾害', '致', '4人死亡']
# ['洪涝灾害', '致', '级救灾应急响应启动']
# ['失踪死亡人数', '上升至', '10人']
# ['甘肃省天水市暴雨', '致', '4人失踪']
# ['秦州暴洪群发性地质灾害', '造成', '54826人受灾']
# ['甘肃', '突发', '特大洪灾']
# ['甘肃', '突发', '特大洪灾']
# ['乡', '发生', '洪灾']
# ['暴洪', '致', '万人受灾']
# ['部分地区', '发生', '山洪泥石流']
# ['部分地区', '遭受', '6人失踪']
# ['暴洪泥石流', '造成', '受灾']
# ['等定西地', '遭', '洪涝灾害']
# ['泥石流灾害', '致', '26']
# ['已', '致', '26']
# ['泥石流灾害致26人', '遇难', '75人失踪']
# ['等庆阳地', '遭受', '3人洪涝灾害死亡']
# ['等庆阳地', '遭受', '洪涝灾害']
# ['甘肃陇南成县洪灾', '致', '18人死亡']
# ['暴洪灾害', '致', '37人遇难']
# ['暴洪灾害', '致', '37人遇难']
# ['遇难人数', '增至', '33人']
# ['洪涝灾害', '致', '34']
# ['抗洪抢险', '面临', '4困难']
# ['等甘南地', '遭受', '洪涝灾害']
# ['遇难人数', '上升至', '54人']
# ['甘部分地区', '遭受', '洪涝灾害']
# ['甘部分地区遭受洪涝灾害', '造成', '2死失踪']
# ['两省', '遭', '洪涝灾害']
# ['等江西省', '遭受', '洪涝灾害']
# ['福建洪灾', '致', '41亿']
# ['6', '亡', '4失踪']
# ['福建清流', '遭遇', '暴雨']
# ['9省市区', '遭', '洪涝灾害']
# ['洪涝灾害', '造成', '4.28亿元经济损失']
# ['等龙岩地', '遭', '3400万']
# ['红十字会总会启', '救助', '洪涝灾区']
# ['受灾人数', '已逾', '2万']
# ['特大山洪灾害', '造成', '1117人遇难']
# ['舟曲强降雨', '引发', '4240人受灾']
# ['地质灾害', '致', '1434人遇难']
# ['地震灾区', '遭遇', '特大洪灾']
# ['洪涝灾情', '致', '1人失踪']
# ['等华南地', '遭受', '洪涝灾害']
# ['等华南地遭受洪涝灾害', '致', '广西云南9死']
# ['部分地区', '遭', '洪涝灾害']
# ['暴雨灾害', '造成', '26人死亡']
# ['西南局地', '发生', '洪涝灾害']
# ['西南局地强降雨', '引发', '洪涝风雹灾害']
# ['西南局地', '遭受', '洪涝灾害']
# ['西南局地', '遭受', '洪涝灾害']
# ['一带', '现', '洪涝风雹灾害']
# ['部分地区', '遭受', '洪涝灾害']
# ['部分地区遭受洪涝灾害', '造成', '5人死亡']
# ['西双版纳', '引发', '勐腊2.9景洪万人受灾']
# ['西安小峪山洪灾害遇难者', '上升至', '8人']
# ['日暴雨', '致', '20余万人受灾']
# ['西藏局部地区', '遭受', '洪涝灾害']
# ['黔部分地区', '遭受', '4人洪涝灾害死亡']
# ['14县市', '遭受', '洪涝灾害']
# ['贵州', '导致', '57.6万人受灾']
# ['多地', '遭受', '暴雨灾害']
# ['贵州局地', '遭', '1人洪涝灾害遇难']
# ['贵州局部', '遭受', '14万人受灾']
# ['贵州强降水', '引发', '22万人受灾']
# ['贵州暴雨洪涝', '致', '31人死亡']
# ['受灾人口', '增至', '40余万']
# ['经济损失', '逾', '7亿元']
# ['贵州望谟县', '遭遇', '14人死亡灾害']
# ['洪涝灾害死亡人数', '上升至', '21人']
# ['贵州正安', '发生', '山洪灾害']
# ['贵州正安发生山洪灾害', '造成', '5人遇难']
# ['等铜仁地', '遭', '洪涝风雹灾害']
# ['等铜仁地', '遭', '洪涝风雹灾害']
# ['贵州洪灾', '致', '14人死亡']
# ['贵州', '遭', '国家灾害']
# ['贵州', '陷', '灾害']
# ['贵州', '陷', '灾害']
# ['贵州陷灾害民政部', '启动', '国家级响应']
# ['强降雨', '致', '等洪涝灾害']
# ['赣湘黔局地', '遭受', '洪涝灾害']
# ['黔部分地区', '遭受', '1人致19人死亡灾害失踪']
# ['受灾人口', '逾', '70万']
# ['辽宁吉林局地', '遭受', '洪涝灾害']
# ['辽宁吉林', '遭受', '1人死亡']
# ['辽宁岫岩', '涉', '瞒报洪灾死亡人数']
# ['8人', '指', '38人']
# ['辽宁建平县', '遭受', '洪涝灾害']
# ['辽宁建平县', '遭受', '洪涝灾害']
# ['辽宁抚顺', '中断', '供电通讯']
# ['黑龙江洪水', '543', '万人受灾']
# ['洪涝灾害死亡人数', '升至', '101人']
# ['抚顺洪灾', '致', '15人遇难']
# ['辽宁抚顺洪灾死亡人数', '升至', '101人']
# ['洪灾遇难者人数', '上升至', '15人']
# ['救灾响应等级', '提升至', '三级']
# ['齐肩', '卷走', '村民']
# ['中国', '提升', '其灾害']
# ['响应等级', '提升至', '三级']
# ['直接经济损失', '逾', '61亿']
# ['辽宁', '遭受', '4人失踪']
# ['洪涝灾害', '造成', '35人死亡']
# ['洪涝灾害', '造成', '28人死66人']
# ['28人', '死', '66人']
# ['洪涝灾害', '造成', '6人死亡']
# ['等暴雨灾害', '致', '28人死亡']
# ['洪涝风雹', '致', '受灾']
# ['洪涝灾害', '造成', '175人死亡']
# ['南方暴雨', '致', '26人死亡']
# ['南方暴雨灾害', '造成', '10人死亡']
# ['暴雨', '致', '46人死亡']
# ['等暴雨灾害', '造成', '35人死亡']
# ['暴雨灾害', '造成', '57人死亡']
# ['暴雨', '造成', '47人死亡']
# ['等洪涝灾害', '造成', '70人8省份死亡']
# ['遭洪灾', '超', '赣南灾区村民盼迁移']
# ['6.7万人', '遭', '洪灾']
# ['重庆四川贵州', '遭受', '人亡']
# ['倒塌', '致', '2']
# ['重庆四川', '遭受', '洪涝灾害']
# ['重庆四川', '遭受', '洪涝灾害']
# ['重庆四川', '遭受', '洪涝风雹灾害']
# ['两省市经济损失', '达', '3亿元']
# ['1人', '失踪', '40余房屋']
# ['重庆市', '调拨', '2000万元资金']
# ['重庆市', '遭', '暴雨']
# ['重庆暴雨', '致', '10人死亡']
# ['损失', '超', '10亿']
# ['重庆暴雨', '造成', '65万人受灾']
# ['洪涝灾害', '致', '212.2万人受灾']
# ['百姓', '得', '营救']
# ['重庆潼南', '遭', '洪灾']
# ['重庆璧山区', '遭受', '洪涝灾害']
# ['重庆璧山区', '遭受', '洪涝灾害']
# ['两省', '共计', '9万人受灾']
# ['重庆', '遭', '洪涝灾害']
# ['民政部', '启动', '四级救灾应急响应']
# ['部分区县', '发生', '洪涝灾害']
# ['直接经济损失', '超', '4555万']
# ['等民政部', '启动', '四级救灾响应']
# ['上游四川', '发生', '洪涝灾害']
# ['23人', '死', '30人']
# ['到大雨', '引发', '洪涝灾害']
# ['严重洪灾', '致', '11人死亡']
# ['陕西南部洪灾', '造成', '41人死亡']
# ['41人', '失踪', '107人']
# ['陕西', '升至', '50人']
# ['多地洪涝', '致', '10万余人受灾']
# ['延安强降雨', '致', '7死']
# ['特大洪灾', '致', '2人遇难']
# ['已', '致', '2人遇难']
# ['洪涝灾害', '导致', '35人遇难']
# ['等宝鸡', '遭受', '洪涝灾害']
# ['陕西暴雨', '致', '45万余人']
# ['陕西暴雨', '致', '37人死亡']
# ['陕西暴雨', '致', '38万余人受灾']
# ['陕西暴雨洪灾', '致', '10余万人受灾']
# ['洪涝', '致', '11人死亡']
# ['45.1万人受灾', '造成', '6人死亡']
# ['陕西洪涝灾区民房重建', '参照', '补助政策']
# ['失踪人数', '上升至', '328人']
# ['洪涝灾害', '致', '41人死亡']
# ['等宝鸡', '遭受', '2人死亡灾害']
# ['洪涝', '致', '38万余人受灾']
# ['青海乌兰县', '遭受', '洪涝灾害']
# ['青海乌兰县遭受洪涝灾害', '造成', '24人死亡']
# ['青海乌兰县', '遭受', '洪涝灾害']
# ['青海乌兰县遭受洪涝灾害', '造成', '13人死亡']
# ['青海化隆县', '遭受', '洪涝灾害']
# ['青海化隆县', '遭受', '洪涝灾害']
# ['3人', '失踪', '山洪2人死亡致']
# ['洪涝灾害', '致', '4人死亡']
# ['等海北地', '遭受', '洪涝灾害']
# ['等海北地遭受洪涝灾害', '造成', '2人死亡']
# ['青海湟源洪灾', '造成', '8条道路冲毁']
# ['地', '遭受', '洪涝灾害']
# ['洪涝灾害', '致', '5死']
# ['黄山市', '降', '特大']
# ['宁夏段', '受', '影响12万人受灾']
# ['强降雨', '致', '洪涝灾害']
# ['黑龙江', '遭', '受灾灾害']
# ['部分乡镇', '有', '洪涝灾害']
# ['黑龙江吉林局地', '遭受', '洪涝灾害']
# ['黑龙江', '造成', '453.6万人受灾']
# ['黑龙江', '转移', '23.3万人']
# ['等大兴安岭地', '遭受', '洪涝灾害']
# ['黑龙江局地', '遭', '造成2人死亡']
# ['持续发展', '造成', '3人死亡']
# ['黑龙江洪灾', '致', '损失120亿']
# ['等鸡西地', '遭受', '洪涝灾害']
# ['甘肃部分地区', '遭受', '1人洪涝灾害死亡']
# ['洪涝灾害', '造成', '经济损失']
# ['黑龙江', '遭受', '洪涝灾害']
# ['过水面积', '超', '9成']
# 新闻标题文本三元组提取完成
